# %% [markdown]
# # TextBlob Notebook
#
# Create a notebook with the examples of this tutorial: [Tutorial: QuickStart](https://textblob.readthedocs.io/en/dev/quickstart.html).
#
# Remember to use markdown to organize the notebook and write notes to yourself.
